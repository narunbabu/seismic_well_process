# %%
# from petrel_well_file_readers import *
import numpy as np
# import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
# from sklearn.linear_model import LinearRegression
# import lasio
# from flex_log import FlexXY,FlexLog
from seis_ampl_spectrum import *
# np.save('d11_t_ai_rc_seis.npy',(tnew[:-1],ai_res[:-1,1],rc,seis_data[:-1,1]))
t,ai,rc,seis=np.load('d11_t_ai_rc_seis.npy')

# %%
plt.subplot(2, 1, 1)
plt.plot(t, 4*rc, 'b-', label='RC')
plt.plot(t,(ai-np.mean(ai))/max(ai))
plt.xlabel('Time [sec]')
plt.grid()
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(t, seis, 'r-', label='seis_data')
plt.xlabel('Time [sec]')
plt.grid()
plt.legend()
